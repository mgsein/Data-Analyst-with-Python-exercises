# %%
import pandas as pd

oil = pd.read_csv('oil.csv')

oil['benchmark'] = 100

oil.head()
# Out:
#          date  dcoilwtico  benchmark
# 0  2013-01-01         NaN        100
# 1  2013-01-02       93.14        100
# 2  2013-01-03       92.97        100
# 3  2013-01-04       93.12        100
# 4  2013-01-07       93.20        100

# %%
mask = ((oil['dcoilwtico'] > oil['benchmark']) & 
        (oil['date'].str[:4] == '2013'))

# %%
oil.dtypes
# Out:
# date           object
# dcoilwtico    float64
# benchmark       int64
# dtype: object

# %%
oil.query('dcoilwtico > benchmark or date.str[:4]')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\collections\__init__.py:1006, in ChainMap.__getitem__(self, key)
#    1005         pass
# -> 1006 return self.__missing__(key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\collections\__init__.py:998, in ChainMap.__missing__(self, key)
#     997 def __missing__(self, key):
# --> 998     raise KeyError(key)
#
# KeyError: 'slice'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
oil = pd.read_csv('oil.csv', parse_dates=['date'])

oil['benchmark'] = 100

oil.head()
# Out:
#         date  dcoilwtico  benchmark
# 0 2013-01-01         NaN        100
# 1 2013-01-02       93.14        100
# 2 2013-01-03       92.97        100
# 3 2013-01-04       93.12        100
# 4 2013-01-07       93.20        100

# %%
oil.dtypes
# Out:
# date          datetime64[ns]
# dcoilwtico           float64
# benchmark              int64
# dtype: object

# %%
oil.query("dcoilwtico > benchmark or date.dt.year == 2013")
# Out:
#           date  dcoilwtico  benchmark
# 0   2013-01-01         NaN        100
# 1   2013-01-02       93.14        100
# 2   2013-01-03       92.97        100
# 3   2013-01-04       93.12        100
# 4   2013-01-07       93.20        100
# ..         ...         ...        ...
# 407 2014-07-24      102.76        100
# 408 2014-07-25      105.23        100
# 409 2014-07-28      105.68        100
# 410 2014-07-29      104.91        100
# 411 2014-07-30      104.29        100
#
# [367 rows x 3 columns]
