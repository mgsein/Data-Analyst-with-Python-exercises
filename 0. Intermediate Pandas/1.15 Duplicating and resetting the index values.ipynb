# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(
        [0, 1, 2, 3, 4], index=['day0', 'day0', 'day0', 'day2', 'day2'] 
)

my_series.index
# Out:
# Index(['day0', 'day0', 'day0', 'day2', 'day2'], dtype='object')

# %%
my_series["day0"]
# Out:
# day0    0
# day0    1
# day0    2
# dtype: int64

# %%
my_series["day2"]
# Out:
# day2    3
# day2    4
# dtype: int64

# %%
my_series.reset_index()
# Out:
#   index  0
# 0  day0  0
# 1  day0  1
# 2  day0  2
# 3  day2  3
# 4  day2  4

# %%
my_series.reset_index(drop=True)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
my_series.reset_index(drop=True).loc[2:4]
# Out:
# 2    2
# 3    3
# dtype: int64

# %%
my_series.reset_index(drop=True).iloc[2:4]
# Out:
# 2    2
# 3    3
# dtype: int64
