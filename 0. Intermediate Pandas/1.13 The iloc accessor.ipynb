# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(
    [0, 1, 2, 3, 4], index=["day0", "day1", "day2", "day3", "day4"]
)

my_series
# Out:
# day0    0
# day1    1
# day2    2
# day3    3
# day4    4
# dtype: int64

# %%
my_series.iloc[0]
# Out:
# 0

# %%
my_series.iloc[-1]
# Out:
# 4

# %%
my_series.iloc[[1, 3, 5]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1715, in _iLocIndexer._get_list_axis(self, key, axis)
#    1714 try:
# -> 1715     return self.obj._take_with_is_copy(key, axis=axis)
#    1716 except IndexError as err:
#    1717     # re-raise with different error message, e.g. test_getitem_ndarray_3d
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4147, in NDFrame._take_with_is_copy(self, indices, axis)
#    4138 """
#    4139 Internal version of the `take` method that sets the `_is_copy`
#    4140 attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4145 See the docstring of `take` for full explanation of the parameters.
#    4146 """
# -> 4147 result = self.take(indices=indices, axis=axis)
# ...

# %%
my_series.iloc[[1, 3, 4]]
# Out:
# day1    1
# day3    3
# day4    4
# dtype: int64

# %%
my_series.iloc[1:4]
# Out:
# day1    1
# day2    2
# day3    3
# dtype: int64
