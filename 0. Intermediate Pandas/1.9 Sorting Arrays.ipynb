# %%
import numpy as np

# %%
product_values = np.array([
    205.4, 158.4, 138.4, 186.24, 6.24, 202.92, 106.44, 3.68, 26.15, 403.2
])

product_values
# Out:
# array([205.4 , 158.4 , 138.4 , 186.24,   6.24, 202.92, 106.44,   3.68,
#         26.15, 403.2 ])

# %%
np.sort(product_values)
# Out:
# array([  3.68,   6.24,  26.15, 106.44, 138.4 , 158.4 , 186.24, 202.92,
#        205.4 , 403.2 ])

# %%
product_values
# Out:
# array([205.4 , 158.4 , 138.4 , 186.24,   6.24, 202.92, 106.44,   3.68,
#         26.15, 403.2 ])

# %%
product_values.sort()

# %%
product_values
# Out:
# array([  3.68,   6.24,  26.15, 106.44, 138.4 , 158.4 , 186.24, 202.92,
#        205.4 , 403.2 ])

# %%
product_values[0]
# Out:
# 3.68

# %%
product_values[-1]
# Out:
# 403.2

# %%
product_values[::-1]
# Out:
# array([403.2 , 205.4 , 202.92, 186.24, 158.4 , 138.4 , 106.44,  26.15,
#          6.24,   3.68])
