# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(range(5))

my_series
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
my_series[3]
# Out:
# 3

# %%
my_series[1:3]
# Out:
# 1    1
# 2    2
# dtype: int64

# %%
my_series[1::2]
# Out:
# 1    1
# 3    3
# dtype: int64

# %%
my_series = pd.Series(range(5), index=["Day0", "Day1", "Day2", "Day3", "Day4"])

my_series
# Out:
# Day0    0
# Day1    1
# Day2    2
# Day3    3
# Day4    4
# dtype: int64

# %%
my_series["Day2"]
# Out:
# 2

# %%
my_series["Day2":"Day4"]
# Out:
# Day2    2
# Day3    3
# Day4    4
# dtype: int64

# %%
my_series[::2]
# Out:
# Day0    0
# Day2    2
# Day4    4
# dtype: int64
