# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(
        [1, 0, 2, 3, 4], index=['day0', 'day1', 'day2', 'day3', 'day4'] 
)

my_series
# Out:
# day0    1
# day1    0
# day2    2
# day3    3
# day4    4
# dtype: int64

# %%
my_series.sort_values()
# Out:
# day1    0
# day0    1
# day2    2
# day3    3
# day4    4
# dtype: int64

# %%
my_series.sort_values(ascending=False)
# Out:
# day4    4
# day3    3
# day2    2
# day0    1
# day1    0
# dtype: int64

# %%
my_series.sort_index()
# Out:
# day0    1
# day1    0
# day2    2
# day3    3
# day4    4
# dtype: int64

# %%
my_series.sort_index(ascending=False)
# Out:
# day4    4
# day3    3
# day2    2
# day1    0
# day0    1
# dtype: int64
