# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(
        [0, 1, 2, 3, 4], index=['day0', 'day1', 'day2', 'day3', 'day4'] 
)

my_series
# Out:
# day0    0
# day1    1
# day2    2
# day3    3
# day4    4
# dtype: int64

# %%
my_series["day2"]
# Out:
# 2

# %%
my_series.loc["day1": "day3"]
# Out:
# day1    1
# day2    2
# day3    3
# dtype: int64

# %%
my_series.index = [0, 2, 3, 100, 5]

# %%
my_series
# Out:
# 0      0
# 2      1
# 3      2
# 100    3
# 5      4
# dtype: int64

# %%
my_series.reset_index(drop=True)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
my_series.reset_index(drop=True).loc[:3]
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64
