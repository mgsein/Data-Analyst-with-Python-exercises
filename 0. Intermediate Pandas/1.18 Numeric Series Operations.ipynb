# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(
        [1, np.NaN, 2, 3, 4], index=['day0', 'day1', 'day2', 'day3', 'day4'] 
)

my_series
# Out:
# day0    1.0
# day1    NaN
# day2    2.0
# day3    3.0
# day4    4.0
# dtype: float64

# %%
my_series + 1
# Out:
# day0    2.0
# day1    NaN
# day2    3.0
# day3    4.0
# day4    5.0
# dtype: float64

# %%
my_series.add(1)
# Out:
# day0    2.0
# day1    NaN
# day2    3.0
# day3    4.0
# day4    5.0
# dtype: float64

# %%
my_series.add(1, fill_value=0)
# Out:
# day0    2.0
# day1    1.0
# day2    3.0
# day3    4.0
# day4    5.0
# dtype: float64

# %%
my_series2 = my_series.add(1, fill_value=0).astype('int')

# %%
my_series2
# Out:
# day0    2
# day1    1
# day2    3
# day3    4
# day4    5
# dtype: int32

# %%
my_series2 / 2
# Out:
# day0    1.0
# day1    0.5
# day2    1.5
# day3    2.0
# day4    2.5
# dtype: float64

# %%
(my_series + my_series * 2) / 2
# Out:
# day0    1.5
# day1    NaN
# day2    3.0
# day3    4.5
# day4    6.0
# dtype: float64
